# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as plt
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

# %%
#read dataset
dataset=pd.read_csv('F:/dataset/data.csv')

# %%
#display first 20 records of dataset
dataset.head(20)
# Out:
#        ID  year loan_limit             Gender approv_in_adv loan_type  \
# 0   24890  2019         cf  Sex Not Available         nopre     type1
# 1   24891  2019         cf               Male         nopre     type2
# 2   24892  2019         cf               Male           pre     type1
# 3   24893  2019         cf               Male         nopre     type1
# 4   24894  2019         cf              Joint           pre     type1
# 5   24895  2019         cf              Joint           pre     type1
# 6   24896  2019         cf              Joint           pre     type1
# 7   24897  2019        NaN             Female         nopre     type1
# 8   24898  2019         cf              Joint         nopre     type1
# 9   24899  2019         cf  Sex Not Available         nopre     type3
# 10  24900  2019         cf               Male         nopre     type2
# 11  24901  2019         cf  Sex Not Available         nopre     type1
# ...

# %%
#Visualization of data
dat=pd.read_csv('F:/dataset/ready.csv')

# %%
fig=plt.figure()
myaxes=fig.add_axes([10.0,10.0,10.0,10.6]) 
myaxes.plot(dat)

# %%
sns.distplot(dat)
# Out:
# C:\Users\Awais\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
#dchecking for outliers
sns.boxplot(dat)
# Out:
# C:\Users\Awais\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %%
#Checking missing values in each attribute
dataset.isnull().sum()
# Out:
# ID                               0
# year                             0
# loan_limit                    3344
# Gender                           0
# approv_in_adv                  908
# loan_type                        0
# loan_purpose                   134
# Credit_Worthiness                0
# open_credit                      0
# business_or_commercial           0
# loan_amount                      0
# rate_of_interest             36439
# Interest_rate_spread         36639
# Upfront_charges              39642
# term                            41
# Neg_ammortization              121
# interest_only                    0
# lump_sum_payment                 0
# property_value               15098
# construction_type                0
# occupancy_type                   0
# Secured_by                       0
# total_units                      0
# income                        9150
# credit_type                      0
# Credit_Score                     0
# co-applicant_credit_type         0
# ...

# %%
#total number of missing values
dataset.isnull().sum().sum()
# Out:
# 181135

# %%
#Removing rows with missing data
new_dat.dropna()
# Out:
#             ID  year loan_type loan_purpose Credit_Worthiness open_credit  \
# 2        24892  2019     type1           p1                l1        nopc
# 4        24894  2019     type1           p1                l1        nopc
# 5        24895  2019     type1           p1                l1        nopc
# 6        24896  2019     type1           p3                l1        nopc
# 8        24898  2019     type1           p3                l1        nopc
# ...        ...   ...       ...          ...               ...         ...
# 148665  173555  2019     type1           p3                l1        nopc
# 148666  173556  2019     type1           p1                l1        nopc
# 148667  173557  2019     type1           p4                l1        nopc
# 148668  173558  2019     type1           p4                l1        nopc
# 148669  173559  2019     type1           p3                l1        nopc
#
#        business_or_commercial  loan_amount  rate_of_interest  \
# ...

# %%
#Total columns of dataset
new_dat.columns
# Out:
# Index(['ID', 'year', 'loan_type', 'loan_purpose', 'Credit_Worthiness',
#        'open_credit', 'business_or_commercial', 'loan_amount',
#        'rate_of_interest', 'Interest_rate_spread', 'Upfront_charges', 'term',
#        'Neg_ammortization', 'interest_only', 'lump_sum_payment',
#        'property_value', 'construction_type', 'occupancy_type', 'Secured_by',
#        'total_units', 'income', 'credit_type', 'Credit_Score',
#        'co-applicant_credit_type', 'age', 'submission_of_application', 'LTV',
#        'Region', 'Security_Type', 'Status', 'dtir1', 'cf', 'ncf', 'Female',
#        'Joint', 'Male', 'Sex Not Available', 'nopre', 'pre'],
#       dtype='object')

# %%
# unique values in  column
new_dat.loan_type.unique()
# Out:
# array(['type1', 'type3', 'type2'], dtype=object)

# %%
#after data cleaning and removing rows with missing data
new_dat.isnull().sum().sum()
# Out:
# 0

# %%
#labelizinig the data 
encoderType=LabelEncoder()
new_dat['loan_type']=encoderType.fit_transform(new_inp.iloc[:,2].values)

# %%
#After labelizing the data saving the new csv file
new_dat.to_csv('ready.csv',header=True,index=True)

# %%
#read data from new csv file beinig lablized
new_dat=pd.read_csv('F:/dataset/ready.csv')

# %%
new_dat
# Out:
#        Unnamed: 0      ID  year  loan_limit  Gender  approv_in_adv  loan_type  \
# 0               2   24892  2019           0       2              0          0
# 1               4   24894  2019           0       1              0          0
# 2               5   24895  2019           0       1              0          0
# 3               6   24896  2019           0       1              0          0
# 4               8   24898  2019           0       1              0          0
# ...           ...     ...   ...         ...     ...            ...        ...
# 98182      148665  173555  2019           0       3              0          0
# 98183      148666  173556  2019           0       2              0          0
# 98184      148667  173557  2019           0       2              0          0
# 98185      148668  173558  2019           0       0              0          0
# 98186      148669  173559  2019           0       0              0          0
#
# ...

# %%
#setting target attribute 'Status'
target=new_dat.Status
inp=new_dat.drop('Status',axis='columns')

# %%
#Splitting data into Train and Test
X=dat.iloc[:,:].values
Y=dat.iloc[:,].values
from sklearn.model_selection import train_test_split
X_Train,X_Test,Y_Train,Y_Test=train_test_split(inp,target,test_size=0.20)

# %%
#feeding data to KNN
from sklearn.neighbors import KNeighborsClassifier
classifier=KNeighborsClassifier(n_neighbors=5)
classifier.fit(X_Train,Y_Train)
# Out:
# KNeighborsClassifier()

# %%
#predicting score on test data
y_pred=classifier.score(X_Test,Y_Test)
print(y_pred)
# Out:
# C:\Users\Awais\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# 1.0

# %%
# Using Naive Bayes Classifer
from sklearn.naive_bayes import GaussianNB
classifier=GaussianNB()

# %%
classifier.fit(X_Train,Y_Train)
# Out:
# GaussianNB()

# %%
classifier.score(X_Test,Y_Test)
# Out:
# 1.0

# %%
#Using Decision Tree Classifier
from sklearn.tree import DecisionTreeClassifier
classifier=DecisionTreeClassifier(random_state=0)

# %%
classifier.fit(X_Train,Y_Train)
# Out:
# DecisionTreeClassifier(random_state=0)

# %%
classifier.score(X_Test,Y_Test)
# Out:
# 1.0
